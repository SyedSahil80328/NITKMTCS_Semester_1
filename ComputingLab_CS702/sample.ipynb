# %%
print("Hello!")
# Out:
# Hello!

# %%
# !whisper
# Out:
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR]
#                [--output_format {txt,vtt,srt,tsv,json,jsonl,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...

# %%
import whisper

model = whisper.load_model("turbo")
result = model.transcribe("F:/DEV_TECH/NITKMTCS_Semester_1/ComputingLab_CS702/sample.mp4")

for segment in result["segments"]:
    print(f"[{segment['start']:.2f} --> {segment['end']:.2f}] {segment['text']}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import whisper
#       2
# ----> 3 model = whisper.load_model("turbo")
#       4 result = model.transcribe("F:/DEV_TECH/NITKMTCS_Semester_1/ComputingLab_CS702/sample.mp4")
#       5
#       6 for segment in result["segments"]:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\whisper\__init__.py:156, in load_model(name, device, download_root, in_memory)
#     154 dims = ModelDimensions(**checkpoint["dims"])
#     155 model = Whisper(dims)
# --> 156 model.load_state_dict(checkpoint["model_state_dict"])
#     158 if alignment_heads is not None:
#     159     model.set_alignment_heads(alignment_heads)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\nn\modules\module.py:2618, in Module.load_state_dict(self, state_dict, strict, assign)
#    2611         if out is not None:
# ...
