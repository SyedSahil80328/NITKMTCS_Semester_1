# %%
print("Hello!")
# Out:
# Hello!

# %%
# !whisper
# Out:
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR]
#                [--output_format {txt,vtt,srt,tsv,json,jsonl,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
#                [--language {af,am,ar,as,az,ba,be,bg,bn,bo,br,bs,ca,cs,cy,da,de,el,en,es,et,eu,fa,fi,fo,fr,gl,gu,ha,haw,he,hi,hr,ht,hu,hy,id,is,it,ja,jw,ka,kk,km,kn,ko,la,lb,ln,lo,lt,lv,mg,mi,mk,ml,mn,mr,ms,mt,my,ne,nl,nn,no,oc,pa,pl,ps,pt,ro,ru,sa,sd,si,sk,sl,sn,so,sq,sr,su,sv,sw,ta,te,tg,th,tk,tl,tr,tt,uk,ur,uz,vi,yi,yo,yue,zh,Afrikaans,Albanian,Amharic,Arabic,Armenian,Assamese,Azerbaijani,Bashkir,Basque,Belarusian,Bengali,Bosnian,Breton,Bulgarian,Burmese,Cantonese,Castilian,Catalan,Chinese,Croatian,Czech,Danish,Dutch,English,Estonian,Faroese,Finnish,Flemish,French,Galician,Georgian,German,Greek,Gujarati,Haitian,Haitian Creole,Hausa,Hawaiian,Hebrew,Hindi,Hungarian,Icelandic,Indonesian,Italian,Japanese,Javanese,Kannada,Kazakh,Khmer,Korean,Lao,Latin,Latvian,Letzeburgesch,Lingala,Lithuanian,Luxembourgish,Macedonian,Malagasy,Malay,Malayalam,Maltese,Mandarin,Maori,Marathi,Moldavian,Moldovan,Mongolian,Myanmar,Nepali,Norwegian,Nynorsk,Occitan,Panjabi,Pashto,Persian,Polish,Portuguese,Punjabi,Pushto,Romanian,Russian,Sanskrit,Serbian,Shona,Sindhi,Sinhala,Sinhalese,Slovak,Slovenian,Somali,Spanish,Sundanese,Swahili,Swedish,Tagalog,Tajik,Tamil,Tatar,Telugu,Thai,Tibetan,Turkish,Turkmen,Ukrainian,Urdu,Uzbek,Valencian,Vietnamese,Welsh,Yiddish,Yoruba}]
#                [--temperature TEMPERATURE] [--best_of BEST_OF]
#                [--beam_size BEAM_SIZE] [--patience PATIENCE]
#                [--length_penalty LENGTH_PENALTY]
#                [--suppress_tokens SUPPRESS_TOKENS]
#                [--initial_prompt INITIAL_PROMPT]
#                [--carry_initial_prompt CARRY_INITIAL_PROMPT]
#                [--condition_on_previous_text CONDITION_ON_PREVIOUS_TEXT]
#                [--fp16 FP16]
#                [--temperature_increment_on_fallback TEMPERATURE_INCREMENT_ON_FALLBACK]
#                [--compression_ratio_threshold COMPRESSION_RATIO_THRESHOLD]
#                [--logprob_threshold LOGPROB_THRESHOLD]
#                [--no_speech_threshold NO_SPEECH_THRESHOLD]
#                [--word_timestamps WORD_TIMESTAMPS]
#                [--prepend_punctuations PREPEND_PUNCTUATIONS]
#                [--append_punctuations APPEND_PUNCTUATIONS]
#                [--highlight_words HIGHLIGHT_WORDS]
#                [--max_line_width MAX_LINE_WIDTH]
#                [--max_line_count MAX_LINE_COUNT]
#                [--max_words_per_line MAX_WORDS_PER_LINE] [--threads THREADS]
#                [--clip_timestamps CLIP_TIMESTAMPS]
#                [--hallucination_silence_threshold HALLUCINATION_SILENCE_THRESHOLD]
#                audio [audio ...]
# whisper: error: the following arguments are required: audio

# %%
import whisper

model = whisper.load_model("turbo")

# %%
result = model.transcribe("sample.mp4")
for segment in result["segments"]:
    print(f"[{segment['start']:.2f} --> {segment['end']:.2f}] {segment['text']}")
# Out:
# C:\Users\salma\AppData\Roaming\Python\Python313\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [0.16 --> 5.32]  Remember when your 10th grade teacher told you, just work hard now, 11th and 12th will
# [5.32 --> 6.48]  be your cakewalk.
# [6.48 --> 9.84]  And then in 12th, they said, just clear the entrance exam.
# [9.84 --> 13.12]  Once you get into a good college, life is sorted.
# [13.12 --> 17.36]  That is officially the biggest scam in the history of Indian education.
# [17.36 --> 22.26]  Because when you enter college, reality doesn't hit you on day one.
# [22.26 --> 24.40]  In fact, the opposite happens.
# [24.40 --> 28.88]  Your first year is probably the most fun you've had in years.
# [28.88 --> 34.44]  New friends, college fest, hostel memories, late night chai sessions, endless freedom.
# [34.44 --> 38.84]  For the first time, it feels like you can relax finally.
# [38.84 --> 43.42]  Then the second year comes around and life still feels pretty chill.
# [43.42 --> 46.60]  You kept telling yourself, there's plenty of time.
# [46.60 --> 49.26]  And that's the dangerous part.
# [49.26 --> 53.48]  Nobody sits you down and tells you, bro, start building your resume.
# [53.48 --> 55.72]  Bro, learn skills around the classroom.
# [55.72 --> 58.82]  Bro, internships don't magically appear in five years.
# [58.82 --> 64.00]  Maybe you'll be hearing those words, but nobody makes them feel urgent.
# [64.00 --> 69.32]  So you keep on pushing them to tomorrow until one day in your third year, reality shows up
# [69.32 --> 70.32]  uninvited.
# [70.32 --> 72.76]  A friend lands an internship.
# [72.76 --> 74.78]  Someone has already built projects.
# [74.78 --> 80.68]  Someone else has a LinkedIn profile that looks more impressive than your entire college journey.
# [80.68 --> 85.86]  But suddenly, the future felt years away, is standing right in front of you.
# [85.86 --> 88.64]  So look at me as your senior for the next few minutes.
# [88.64 --> 92.38]  I'm going to tell you the exact four traps you need to dodge right now.
# [92.38 --> 96.08]  So you don't end up in the third year wondering where all the time went.
# [96.08 --> 99.86]  And trust me, the number four catches almost everyone.
# [99.86 --> 104.04]  Let's start with the academics.
# [104.04 --> 107.04]  Because this is where the first trap appears.
# [107.04 --> 112.14]  Within your first few weeks, you'll probably sitting in the cafeteria when some cool senior
# [112.14 --> 113.36]  casually drops the line.
# [113.36 --> 114.36]  Bro, relax.
# [114.36 --> 117.04]  A 7 CGPA is more than enough.
# [117.04 --> 119.04]  College exams are easy.
# [119.04 --> 120.04]  Just tidy the night before.
# [120.04 --> 121.04]  Sounds great, right?
# [121.04 --> 123.04]  Here's the part nobody tells you.
# [123.04 --> 126.04]  A high CGPA won't magically get your place.
# [126.04 --> 133.04]  But a low CGPA can quietly eliminate opportunities before you even get a chance to complete them.
# [133.04 --> 138.40]  The first year is usually the easiest time to score well because the syllabus is still broad
# [138.40 --> 140.40]  and relatively manageable.
# [140.40 --> 144.76]  If you completely switch off now, you'll spend your second and third year desperately trying
# [144.76 --> 148.44]  to pull your average up just to qualify for company eligibility.
# [148.44 --> 153.98]  I'm telling you not to create a problem that future you has to spend three years fixing.
# [153.98 --> 156.20]  Secure your grades while it's easier.
# [156.20 --> 163.06]  So later you can focus on internships, projects, competitions and actual skills without constantly
# [163.06 --> 165.04]  worrying about cut-offs.
# [165.04 --> 166.20]  Trap No. 2.
# [166.20 --> 170.44]  Joining every club and society just because everyone else is doing it.
# [170.44 --> 176.04]  You want to be in the dance club, the marketing club, the tech cell, the photography club, the
# [176.04 --> 179.58]  theatre society and somehow still have time to sleep.
# [179.58 --> 181.58]  Look, clubs are amazing.
# [181.58 --> 187.64]  They are one of the fastest ways to make friends, build confidence and figure out what you actually
# [187.64 --> 188.74]  enjoy.
# [188.74 --> 191.80]  But some students get addicted to being busy.
# [191.80 --> 197.58]  Their entire week becomes meetings, event planning, volunteer work and company discussions.
# [197.58 --> 201.12]  They are always occupied, but they are not actually growing.
# [201.12 --> 206.30]  Soon they are running event management at 9pm, skipping morning classes and wondering why they
# [206.30 --> 210.26]  never have time to learn anything useful.
# [210.26 --> 213.16]  Pick one or two societies that genuinely excites you.
# [213.16 --> 215.12]  Go deep instead of going everywhere.
# [215.12 --> 218.34]  Remember, your goal isn't to collect positions.
# [218.34 --> 221.52]  It's to collect experiences and skills.
# [221.52 --> 227.28]  The mistake is ignoring your resume until the companies are literally knocking on the campus.
# [227.28 --> 230.24]  This happens way more often than you think.
# [230.24 --> 234.66]  Most students enter college thinking they had plenty of time.
# [234.66 --> 236.14]  First year disappears.
# [236.14 --> 238.88]  Second year disappears even faster.
# [238.88 --> 244.14]  Then one random day, someone in your classroom lands an internship.
# [244.14 --> 247.86]  Another person starts posting projects, updates on LinkedIn.
# [247.86 --> 253.14]  Someone else suddenly has certificates, hackathon wins and a portfolio.
# [253.14 --> 255.40]  And that's when the panic begins.
# [255.40 --> 257.86]  Because college is in school.
# [257.86 --> 260.70]  Nobody is going to check whether you're building projects.
# [260.70 --> 263.76]  Nobody is going to remind you to learn new tools.
# [263.76 --> 267.78]  Nobody is going to sit next to you and make sure you're improving.
# [267.78 --> 269.78]  You have to do it yourself.
# [269.78 --> 273.24]  You don't need to build your next unicorn startup in the first semester.
# [273.24 --> 274.24]  Start something.
# [274.24 --> 275.24]  Build a small project.
# [275.24 --> 277.24]  Learn a useful tool.
# [277.24 --> 278.24]  Create a portfolio.
# [278.24 --> 282.24]  And if you are a computer science student, contribute to an open source.
# [282.24 --> 283.24]  Freelance.
# [283.24 --> 284.24]  Write.
# [284.24 --> 285.24]  Design.
# [285.24 --> 286.24]  Code.
# [286.24 --> 292.24]  And please stop treating your GitHub profile like a graveyard for half-finished assignments.
# [292.24 --> 296.92]  Recruiters have already seen thousands of basic library management systems and e-commerce
# [296.92 --> 297.92]  clones.
# [297.92 --> 300.48]  They don't just want to know what you've built for marks.
# [300.48 --> 303.82]  They want to know what you've built because you are curious.
# [303.82 --> 308.76]  And if you're serious about standing out, start exploring programs like GSOC or Outreachy
# [308.76 --> 309.76]  early.
# [309.76 --> 311.72]  Not because they look cool on LinkedIn.
# [311.72 --> 316.16]  Because they teach you how real-world software is actually built.
# [316.16 --> 318.64]  The goal isn't to impress the recruiters.
# [318.64 --> 323.34]  The goal is to become the kind of a person recruiters can't ignore.
# [323.34 --> 328.68]  Now let's talk about the trap that catches more students than any syllabus ever could.
# [328.68 --> 330.48]  Your friend's circle.
# [330.48 --> 332.66]  Because this trap doesn't look dangerous.
# [332.66 --> 334.00]  It looks fun.
# [334.00 --> 337.28]  In college, the guardrails disappears.
# [337.28 --> 340.34]  Your parents aren't checking whether you attended classes.
# [340.34 --> 343.96]  Your professors aren't calling home because you skipped a lecture.
# [343.96 --> 347.30]  For the first time, your life is your responsibility.
# [347.30 --> 350.96]  And the people around you become your default setting.
# [350.96 --> 356.12]  If your squad's main hobby is skipping classes, wasting entire afternoon, spending money they
# [356.12 --> 360.30]  don't have, and complaining about everything, guess what?
# [360.30 --> 363.30]  You'll slowly start doing the exact same thing.
# [363.30 --> 365.22]  Not because you're weak.
# [365.22 --> 370.12]  Because humans naturally become like the people they spend the most time with.
# [370.12 --> 374.92]  Be friendly with everyone, but choose your inner circle carefully.
# [374.92 --> 378.50]  Find the people who are ambitious without being annoying.
# [378.50 --> 384.38]  The people who are excited about hackathons, projects, competitions, startups, creative work,
# [384.38 --> 386.22]  or learning something new.
# [386.22 --> 390.46]  The people who can celebrate hard, but also work hard.
# [390.46 --> 394.64]  Those friendships will change your entire college experience.
# [394.64 --> 400.36]  And if someone consistently pulls your growth backwards, start creating some distance.
# [400.36 --> 402.14]  It sounds harsh, I know.
# [402.14 --> 404.92]  But your future self will thank you for it.
# [404.92 --> 408.86]  At the end of the day, college is one of the few phases in your life where you're allowed
# [408.86 --> 415.34]  to make mistakes, experiment, fail, recover, and reinvent yourself.
# [415.34 --> 418.18]  Nobody here knows where you were in school.
# [418.18 --> 421.36]  Nobody cares about embarrassing moments from your 12th grade.
# [421.36 --> 423.52]  You get a completely fresh start.
# [423.52 --> 425.36]  So enjoy it.
# [425.36 --> 426.86]  Go to the fest.
# [426.86 --> 429.40]  Stay up late thinking nonsense with your friends.
# [429.40 --> 430.40]  Take photos.
# [430.40 --> 431.48]  Record videos.
# [431.48 --> 434.96]  Make memories you laugh about 10 years from now.
# [434.96 --> 439.08]  Just don't make the mistake of thinking college is only about fun.
# [439.08 --> 444.90]  Because one day, you'll wake up, look at the calendar, and realize graduation isn't some
# [444.90 --> 445.90]  distant event anymore.
# [445.90 --> 448.08]  It's right around the corner.
# [448.08 --> 454.90]  And when the day comes, you'll either be grateful for how you spent these years, or you'll wish
# [454.90 --> 457.48]  you could start it all over again.
# [457.48 --> 462.04]  So tell me, which one of these traps do you think students fall in the most?
# [462.04 --> 465.22]  And most importantly, which one are you trying to avoid?
# [465.22 --> 466.04]  And don't I want you.
